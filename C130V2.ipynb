# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavKumar07/C130/blob/main/C130V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-NASA-Exoplanet-Processed-Data
# Out:
# Cloning into 'PRO-NASA-Exoplanet-Processed-Data'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 6 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), 684.49 KiB | 14.56 MiB/s, done.

# %%
import pandas as pd

final_planets_df = pd.read_csv("/content/PRO-NASA-Exoplanet-Processed-Data/final.csv")

print(final_planets_df.shape)
# Out:
# (4284, 85)

# %%
final_planets_df.head()
# Out:
#                    name  light_years_from_earth     planet_mass  \
# 0  11 Comae Berenices b                   305.0   19.4 Jupiters
# 1    11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2       14 Andromedae b                   247.0    4.8 Jupiters
# 3         14 Herculis b                    59.0   4.66 Jupiters
# 4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar_magnitude  discovery_date  \
# 0              4.740            2007
# 1              5.016            2009
# 2              5.227            2008
# 3              6.610            2002
# 4              6.250            1996
#
#                                            hyperlink planet_type  \
# 0  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# 1  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# 2  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# 3  https://exoplanets.nasa.gov/exoplanet-catalog/...   Gas Giant
# ...

# %%
final_planets_df.columns
# Out:
# Index(['name', 'light_years_from_earth', 'planet_mass', 'stellar_magnitude',
#        'discovery_date', 'hyperlink', 'planet_type', 'temp_planet_date',
#        'temp_planet_mass', 'planet_radius', 'orbital_radius', 'orbital_period',
#        'eccentricity', 'pl_hostname', 'pl_letter', 'pl_name', 'pl_discmethod',
#        'pl_controvflag', 'pl_pnum', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_orbincl', 'pl_orbinclerr1',
#        'pl_orbinclerr2', 'pl_orbincllim', 'pl_bmassj', 'pl_bmassjerr1',
#        'pl_bmassjerr2', 'pl_bmassjlim', 'pl_bmassprov', 'pl_radj',
#        'pl_radjerr1', 'pl_radjerr2', 'pl_radjlim', 'pl_dens', 'pl_denserr1',
#        'pl_denserr2', 'pl_denslim', 'pl_ttvflag', 'pl_kepflag', 'pl_k2flag',
#        'pl_nnotes', 'ra_str', 'ra', 'dec_str', 'dec', 'st_dist', 'st_disterr1',
# ...

# %%
final_planets_df.drop(columns = ['hyperlink', 'temp_planet_date', 'temp_planet_mass', 'pl_letter', 'pl_name',
                                 'pl_controvflag', 'pl_pnum', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2',
                                 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_orbsmaxlim',
                                 'pl_orbeccen', 'pl_orbeccenerr1', 'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_orbinclerr1',
                                 'pl_orbinclerr2', 'pl_orbincllim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
                                 'pl_bmassjlim', 'pl_bmassprov', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2', 'pl_radjlim',
                                 'pl_denserr1', 'pl_denserr2', 'pl_denslim', 'pl_ttvflag', 'pl_kepflag', 'pl_k2flag',
                                 'pl_nnotes', 'ra', 'dec', 'st_dist', 'st_disterr1', 'st_disterr2', 'st_distlim',
                                 'gaia_dist', 'gaia_disterr1', 'gaia_disterr2', 'gaia_distlim', 'st_optmag', 'st_optmagerr',
                                 'st_optmaglim', 'st_optband', 'gaia_gmag', 'gaia_gmagerr', 'gaia_gmaglim', 'st_tefferr1',
                                 'st_tefferr2', 'st_tefflim', 'st_masserr1', 'st_masserr2'], inplace=True)
print(final_planets_df.shape)
# Out:
# (4284, 25)

# %%
final_planets_df = final_planets_df.rename({
    "pl_hostname": "solar_system_name",
    "pl_discmethod" : "planet_discovery_method",
    "pl_orbincl" : "planet_orbital_inclination",
    "pl_dens" : "planet_density",
    "ra_str" : "right_ascension",
    "dec_str" : "declination",
    "st_deff" : "host_temperature",
    "st_mass" : "host_mass",
    "st_rad" : "host_radius",
} , axis = "columns")

final_planets_df.head(10)
# Out:
#                       name  light_years_from_earth     planet_mass  \
# 0     11 Comae Berenices b                   305.0   19.4 Jupiters
# 1       11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2          14 Andromedae b                   247.0    4.8 Jupiters
# 3            14 Herculis b                    59.0   4.66 Jupiters
# 4             16 Cygni B b                    69.0   1.78 Jupiters
# 5            18 Delphini b                   249.0   10.3 Jupiters
# 6  1RXS J160929.1-210524 b                   473.0      8 Jupiters
# 7              24 Bootis b                   314.0   0.91 Jupiters
# 8           24 Sextantis b                   236.0   1.99 Jupiters
# 9           24 Sextantis c                   236.0   0.86 Jupiters
#
#    stellar_magnitude  discovery_date planet_type    planet_radius  \
# 0              4.740            2007   Gas Giant   1.08 x Jupiter
# 1              5.016            2009   Gas Giant   1.09 x Jupiter
# ...

# %%
final_planets_df.to_csv("main.csv")
from google.colab import files
files.download("main.csv")
